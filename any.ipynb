# %%
from pathlib import Path

nav = Path("/Users/jg/projects/ecameo/Integrated/app.py")

print(nav)
# Out:
# /Users/jg/projects/ecameo/Integrated/app.py

# %%
print(nav.parent)
# Out:
# /Users/jg/projects/ecameo/Integrated

# %%
print(nav.name)
# Out:
# app.py

# %%
from flask import Flask

app = Flask(__name__)

@app.route("/")
def home():
    return "Hello World"

# %%
home()
# Out:
# 'Hello World'
